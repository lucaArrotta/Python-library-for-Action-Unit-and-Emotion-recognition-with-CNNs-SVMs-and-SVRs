# %% [markdown]
# # Testing
# In this notebook we'll test the lib functions implemented in "au_lib.py" file.
# 1. __get_img_aus_occurencies__: Returns the list of the AUs detected inside the input image
# 2. __get_img_emotions_occurencies__: Returns a dict in which at each emotion is associated the percentage of AUs that appear in the input image
# 3. __get_img_aus_intensities__: hello
# 4. __get_img_emotions_intensities__: hello

# %% [markdown]
# <img src="images/AU.png" width="400">

# %% [markdown]
# <img src="images/emotions.png">

# %%
import au_lib
from face_helpers import show_image_from_path
from PIL import Image

# %% [markdown]
# <br>
# SVM tests.

# %%
print("AUs:  ", au_lib.get_img_aus_occurencies("images/test_happiness.png"))
print("Emotions: ", au_lib.get_img_emotions_occurencies("images/test_happiness.png"))
img = Image.open("images/test_happiness.png")
show_image_from_path("images/test_happiness.png")
# Out:
# get_img_aus:   [1, 2, 4, 5, 6, 7, 9, 12, 14, 16, 20, 23, 26]
# img_emotions:  {'happiness': 1.0, 'sadness': 0.67, 'surprise': 1.0, 'fear': 1.0, 'anger': 1.0, 'disgust': 0.67}

# %%
img = Image.open("images/test_sadness.jpg")
print("AUs:  ", au_lib.get_img_aus_occurencies(img))
print("Emotions: ", au_lib.get_img_emotions_occurencies(img))
show_image_from_path("images/test_sadness.jpg")
# Out:
# get_img_aus:   [15, 23, 26]
# img_emotions:  {'happiness': 0.0, 'sadness': 0.33, 'surprise': 0.25, 'fear': 0.14, 'anger': 0.25, 'disgust': 0.33}

# %%
img = Image.open("images/test_surprise.jpg")
print("AUs:  ", au_lib.get_img_aus_occurencies(img))
print("Emotions: ", au_lib.get_img_emotions_occurencies(img))
show_image_from_path("images/test_surprise.jpg")
# Out:
# get_img_aus:   [4, 6, 14, 16, 20, 23, 26]
# img_emotions:  {'happiness': 0.5, 'sadness': 0.33, 'surprise': 0.25, 'fear': 0.43, 'anger': 0.5, 'disgust': 0.33}

# %%
img = Image.open("images/test_fear.jpg")
print("AUs:  ", au_lib.get_img_aus_occurencies(img))
print("Emotions: ", au_lib.get_img_emotions_occurencies(img))
show_image_from_path("images/test_fear.jpg")
# Out:
# get_img_aus:   [2, 4, 7, 9, 14, 15, 16, 20, 23, 26]
# img_emotions:  {'happiness': 0.0, 'sadness': 0.67, 'surprise': 0.5, 'fear': 0.71, 'anger': 0.75, 'disgust': 1.0}

# %%
img = Image.open("images/test_anger.jpg")
print("AUs:  ", au_lib.get_img_aus_occurencies(img))
print("Emotions: ", au_lib.get_img_emotions_occurencies(img))
show_image_from_path("images/test_anger.jpg")
# Out:
# get_img_aus:   [2, 4, 5, 9, 14, 15, 16, 20, 23, 26]
# img_emotions:  {'happiness': 0.0, 'sadness': 0.67, 'surprise': 0.75, 'fear': 0.71, 'anger': 0.75, 'disgust': 1.0}

# %%
img = Image.open("images/test_disgust.jpg")
print("AUs:  ", au_lib.get_img_aus_occurencies(img))
print("Emotions: ", au_lib.get_img_emotions_occurencies(img))
show_image_from_path("images/test_disgust.jpg")
# Out:
# get_img_aus:   [1, 4, 7, 9, 15, 16, 23, 26]
# img_emotions:  {'happiness': 0.0, 'sadness': 1.0, 'surprise': 0.5, 'fear': 0.57, 'anger': 0.75, 'disgust': 1.0}

# %% [markdown]
# <br>
# SVR tests.

# %% [markdown]
# ***
